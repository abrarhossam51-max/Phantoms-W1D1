# %% [markdown]
# <a href="https://colab.research.google.com/github/abrarhossam51-max/Phantoms-W1D1/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Phantoms W1D4

# %% [markdown]
# Vs code :
# محرر أكواد مجاني وخفيف الوزن من مايكروسوفت ويُعد الخيار الأول لملايين المبرمجين بفضل سرعته ومرونته العالية
# Pycharm:
# برنامج PyCharm هو أحد أفضل بيئات التطوير المتكاملة (IDE) المخصصة للغة بايثون من شركه JetBrains ويتميز بمجموعه قويه من الأدوات التي تسهل كتابه وتصحيح الأكواد
# Google Colab:
# بيئة عمل سحابيه مجانيه لكتابه وتنفيذ أكواد لغه بايثون عبر المتصفح دون الحاجة لأي إعدادات معقدة على الجهاز
# افضلهم :
# ال VS Code و Google Colab بيديوا مرونه كاملة:
# ​VS Code:
# لمشاريعك الأساسيه تنظيم الملفات وتطوير الويب أو سكريبتات بايثون المحليه
# ​Google Colab:
# أول ما تدخل في قسم الذكاء الاصطناعي تحليل البيانات الضخمه و محتاج كارت شاشه قوي لتشغيل موديل
#
# Virtual Environment :
# أهمية البيئة الافتراضيةتجنب تضارب الإصدارات: تتيح لك تشغيل مشروع قديم يعتمد على إصدار (مثلاً Django 3.0) ومشروع جديد يعتمد على (Django 5.0) على نفس الجهاز دون أي تداخل.الحفاظ على نظافة النظام: تمنع تكدس الحزم والمكتبات في نظام التشغيل الأساسي، مما يحميه من البطء أو المشاكل التقنية.سهولة نقل المشروع ومشاركته: تضمن أن يعمل الكود الخاص بك بنفس الكفاءة والدقة على جهاز أي مبرمج آخر أو على خوادم الاستضافة (Cloud Servers).إدارة دقيقة للملفات: تمكنك من استخراج ملف مثل requirements.txt يحتوي فقط على المكتبات التي يحتاجها هذا المشروع تحديداً.
# أشهر أدوات إنشاء البيئات الافتراضيةتختلف الأدوات بحسب لغة البرمجة المستخدمة، ومن أبرزها:Python:venv: الأداة الرسمية والمدمجة في لغة بايثون.virtualenv: أداة قوية وتوفر ميزات متقدمة وسرعة أعلى.Conda: شائعة جداً في مجالات الذكاء الاصطناعي وعلوم البيانات لإدارة البيئات والحزم معاً.JavaScript / Node.js:تستخدم ملف package.json ومجلد node_modules لعزل حزم كل مشروع تلقائياً.
# Git Branching Strategy:
# استراتيجيه Trunk-Based Development
# مميزات Trunk-Based Development:منع مشاكل الدمج الكبيرة (Merge Hell): دمج الكود باستمرار يمنع اختلاف الفروع لفترات طويلة ويقلل تعارض الأكواد.تسريع التكامل المستمر (CI/CD): يجعل الكود جاهزاً للإصدار والنشر في أي وقت، مما يدعم سرعة دورة حياة التطوير.التشجيع على التعديلات الصغيرة: يدفع المطورين لكتابة مهام صغيرة ومحددة ورفعها أولاً بأول بدلاً من تجميعها في فروع ضخمة.سرعة اكتشاف الأخطاء: يساعد الفحص والاختبار الآلي السريع على اكتشاف المشاكل ومعالجتها فور وقوعها قبل أن تتفاقم.تعاون أفضل: يزيد من تواصل الفريق ويعطي رؤية واضحة عما يعمل عليه الآخرون لحظةً بلحظة.
